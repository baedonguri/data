# %% [markdown]
# # 라이브러리 Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터 읽어들이기

# %%
df = pd.read_excel('test.xlsx', index_col=0)

# %% [markdown]
# # 데이터 확인하기

# %%
df.head(5)
# Out:
#                Y1_1      Y1_2      Y1_3      Y1_4      Y1_5      Y1_6  \
# xy_Corr()
# X1_1       0.748552  0.739775  0.462964  0.100582  0.578452 -0.067193
# X1_2       0.218987  0.238128  0.441753 -0.324680  0.058919 -0.327653
# X1_3       0.395438  0.410710  0.525481 -0.271603  0.204421 -0.317949
# X1_4       0.696166  0.700842  0.694169  0.036324  0.372054 -0.121761
# X1_5       0.379892  0.395676  0.530547 -0.421223  0.173898 -0.438598
#
#                Y1_7      Y1_8      Y1_9     Y1_10
# xy_Corr()
# X1_1       0.298651  0.100960  0.126377  0.088670
# X1_2      -0.292051 -0.209883 -0.130030 -0.277178
# X1_3      -0.190186 -0.166229 -0.086390 -0.231138
# X1_4       0.152042  0.127047  0.240878  0.047669
# X1_5      -0.325944 -0.277462 -0.188630 -0.346413

# %% [markdown]
# # 데이터 시각화 & 이미지파일로 저장

# %%
# %config InlineBackend.figure_format='retina'
plt.figure(figsize = (16, 9))

sns.heatmap(
    data = df,
    annot = True,
    fmt = '.02f',
    linewidths = 5,
    center = 0
).get_figure().savefig('y변수선정 시각화.png', dpi=450)
