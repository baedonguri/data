# %%
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 911kB 3.0MB/s
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup 
import time
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
#!pip install selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup 
import time
import pandas as pd

from google.colab import drive
drive.mount('/content/gdrive/')

driver = webdriver.Chrome('/content/gdrive/My Drive/chromedriver')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ...

# %%
df = pd.read_csv("/content/gdrive/Shared drives/2020 공공빅데이터 서울3반 9조/데이터팀/공동작업실/컬럼목록csv/킹재미전처리.csv", encoding='cp949')

# %%
df
# Out:
#                 행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구
# 0     서울특별시 강남구 역삼1동  11,588  3,374  7,328  15,733  32,466  35,865
# 1      서울특별시 광진구 화양동  11,276    421    739   2,354  24,186  21,441
# 2        경기도 화성시 향남읍  10,992  1,252  1,448   6,291  79,527  82,302
# 3      서울특별시 관악구 신림동  10,468    312    494   1,613  20,279  21,363
# 4      서울특별시 관악구 청룡동  10,308    383    631   1,733  27,211  28,789
# ...              ...     ...    ...    ...     ...     ...     ...
# 3465     강원도 철원군 근동면     NaN    NaN    NaN     NaN     NaN     NaN
# 3466     강원도 철원군 원동면     NaN    NaN    NaN     NaN     NaN     NaN
# 3467     강원도 철원군 원남면     NaN    NaN    NaN     NaN     NaN     NaN
# 3468     강원도 철원군 임남면     NaN    NaN    NaN     NaN     NaN     NaN
# 3469     강원도 고성군 수동면     NaN    NaN    NaN     NaN     NaN     NaN
#
# [3470 rows x 7 columns]

# %%
seoul = df.loc[df['행정구역'].str.contains('서울특별시', na=False)]

# %%
seoul
# Out:
#                 행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구
# 0     서울특별시 강남구 역삼1동  11,588  3,374  7,328  15,733  32,466  35,865
# 1      서울특별시 광진구 화양동  11,276    421    739   2,354  24,186  21,441
# 3      서울특별시 관악구 신림동  10,468    312    494   1,613  20,279  21,363
# 4      서울특별시 관악구 청룡동  10,308    383    631   1,733  27,211  28,789
# 6      서울특별시 관악구 대학동   9,687    169    566   1,522  23,335  23,824
# ...              ...     ...    ...    ...     ...     ...     ...
# 3107   서울특별시 송파구 오륜동     339    187    199     504  18,593  19,228
# 3194  서울특별시 서초구 반포본동     312    230    257     665  10,978  12,528
# 3308  서울특별시 송파구 잠실7동     270     63     76     194   9,267  10,355
# 3457  서울특별시 강동구 둔촌1동      45      8      5      18     134     301
# 3460  서울특별시 송파구 가락1동      14  2,538    105   2,784     708   1,104
#
# [424 rows x 7 columns]

# %%
seoul = seoul.reset_index()

# %%
seoul = seoul.drop(columns = ['level_0','index'] )

# %%
seoul
# Out:
#                행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구
# 0    서울특별시 강남구 역삼1동  11,588  3,374  7,328  15,733  32,466  35,865
# 1     서울특별시 광진구 화양동  11,276    421    739   2,354  24,186  21,441
# 2     서울특별시 관악구 신림동  10,468    312    494   1,613  20,279  21,363
# 3     서울특별시 관악구 청룡동  10,308    383    631   1,733  27,211  28,789
# 4     서울특별시 관악구 대학동   9,687    169    566   1,522  23,335  23,824
# ..              ...     ...    ...    ...     ...     ...     ...
# 419   서울특별시 송파구 오륜동     339    187    199     504  18,593  19,228
# 420  서울특별시 서초구 반포본동     312    230    257     665  10,978  12,528
# 421  서울특별시 송파구 잠실7동     270     63     76     194   9,267  10,355
# 422  서울특별시 강동구 둔촌1동      45      8      5      18     134     301
# 423  서울특별시 송파구 가락1동      14  2,538    105   2,784     708   1,104
#
# [424 rows x 7 columns]

# %%
seoul
# Out:
#                행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구
# 0    서울특별시 강남구 역삼1동  11,588  3,374  7,328  15,733  32,466  35,865
# 1     서울특별시 광진구 화양동  11,276    421    739   2,354  24,186  21,441
# 2     서울특별시 관악구 신림동  10,468    312    494   1,613  20,279  21,363
# 3     서울특별시 관악구 청룡동  10,308    383    631   1,733  27,211  28,789
# 4     서울특별시 관악구 대학동   9,687    169    566   1,522  23,335  23,824
# ..              ...     ...    ...    ...     ...     ...     ...
# 419   서울특별시 송파구 오륜동     339    187    199     504  18,593  19,228
# 420  서울특별시 서초구 반포본동     312    230    257     665  10,978  12,528
# 421  서울특별시 송파구 잠실7동     270     63     76     194   9,267  10,355
# 422  서울특별시 강동구 둔촌1동      45      8      5      18     134     301
# 423  서울특별시 송파구 가락1동      14  2,538    105   2,784     708   1,104
#
# [424 rows x 7 columns]

# %%
seoul.to_csv('진짜 서울.csv')

# %%
a = pd.read_csv("진짜 서울.csv", index_col= 0)
a
b = to_csv("진짜진짜서울.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-4af6b28a73f5> in <module>()
#       1 a = pd.read_csv("진짜 서울.csv", index_col= 0)
#       2 a
# ----> 3 b.to_csv("진짜진짜서울.csv")
#       4 b
#
# NameError: name 'b' is not defined

# %%
pwd
# Out:
# '/content'

# %%
# !ls
# Out:
# '진짜 서울'  '진짜 서울.csv'   gdrive   sample_data

# %%
seoul
# Out:
#                행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구
# 0    서울특별시 강남구 역삼1동  11,588  3,374  7,328  15,733  32,466  35,865
# 1     서울특별시 광진구 화양동  11,276    421    739   2,354  24,186  21,441
# 2     서울특별시 관악구 신림동  10,468    312    494   1,613  20,279  21,363
# 3     서울특별시 관악구 청룡동  10,308    383    631   1,733  27,211  28,789
# 4     서울특별시 관악구 대학동   9,687    169    566   1,522  23,335  23,824
# ..              ...     ...    ...    ...     ...     ...     ...
# 419   서울특별시 송파구 오륜동     339    187    199     504  18,593  19,228
# 420  서울특별시 서초구 반포본동     312    230    257     665  10,978  12,528
# 421  서울특별시 송파구 잠실7동     270     63     76     194   9,267  10,355
# 422  서울특별시 강동구 둔촌1동      45      8      5      18     134     301
# 423  서울특별시 송파구 가락1동      14  2,538    105   2,784     708   1,104
#
# [424 rows x 7 columns]

# %%
seoul_list = list(seoul['행정구역'])

# %%
seoul_list
seoul
# Out:
# ['서울특별시 강남구 역삼1동',
#  '서울특별시 광진구 화양동',
#  '서울특별시 관악구 신림동',
#  '서울특별시 관악구 청룡동',
#  '서울특별시 관악구 대학동',
#  '서울특별시 강서구 가양1동',
#  '서울특별시 관악구 행운동',
#  '서울특별시 강서구 화곡1동',
#  '서울특별시 서대문구 연희동',
#  '서울특별시 서대문구 신촌동',
#  '서울특별시 영등포구 영등포동',
#  '서울특별시 동작구 상도1동',
#  '서울특별시 마포구 서교동',
#  '서울특별시 금천구 가산동',
#  '서울특별시 관악구 서림동',
#  '서울특별시 송파구 문정2동',
#  '서울특별시 동대문구 이문1동',
#  '서울특별시 금천구 독산1동',
#  '서울특별시 노원구 공릉1동',
#  '서울특별시 동대문구 용신동',
#  '서울특별시 강남구 논현1동',
#  '서울특별시 영등포구 당산2동',
#  '서울특별시 관악구 서원동',
#  '서울특별시 구로구 구로3동',
#  '서울특별시 관악구 신사동',
#  '서울특별시 관악구 인헌동',
#  '서울특별시 관악구 낙성대동',
#  '서울특별시 송파구 석촌동',
#  '서울특별시 광진구 군자동',
#  '서울특별시 마포구 성산2동',
#  '서울특별시 강동구 길동',
#  '서울특별시 중랑구 면목본동',
#  '서울특별시 송파구 삼전동',
#  '서울특별시 강동구 천호2동',
#  '서울특별시 성북구 안암동',
#  '서울특별시 동작구 사당1동',
#  '서울특별시 마포구 공덕동',
#  '서울특별시 송파구 잠실본동',
#  '서울특별시 동작구 대방동',
#  '서울특별시 동대문구 전농1동',
#  '서울특별시 은평구 대조동',
#  '서울특별시 성북구 동선동',
#  '서울특별시 중랑구 중화2동',
#  '서울특별시 구로구 구로5동',
#  '서울특별시 성북구 종암동',
#  '서울특별시 강북구 수유3동',
#  '서울특별시 동작구 노량진1동',
#  '서울특별시 성북구 삼선동',
# ...

# %%
seoul_list2 = []
for i in seoul_list:
  var = i.replace("서울특별시 ", '')
  var.strip(' ')
  seoul_list2.append(var)

# %%
seoul_list2
# Out:
# ['강남구 역삼1동',
#  '광진구 화양동',
#  '관악구 신림동',
#  '관악구 청룡동',
#  '관악구 대학동',
#  '강서구 가양1동',
#  '관악구 행운동',
#  '강서구 화곡1동',
#  '서대문구 연희동',
#  '서대문구 신촌동',
#  '영등포구 영등포동',
#  '동작구 상도1동',
#  '마포구 서교동',
#  '금천구 가산동',
#  '관악구 서림동',
#  '송파구 문정2동',
#  '동대문구 이문1동',
#  '금천구 독산1동',
#  '노원구 공릉1동',
#  '동대문구 용신동',
#  '강남구 논현1동',
#  '영등포구 당산2동',
#  '관악구 서원동',
#  '구로구 구로3동',
#  '관악구 신사동',
#  '관악구 인헌동',
#  '관악구 낙성대동',
#  '송파구 석촌동',
#  '광진구 군자동',
#  '마포구 성산2동',
#  '강동구 길동',
#  '중랑구 면목본동',
#  '송파구 삼전동',
#  '강동구 천호2동',
#  '성북구 안암동',
#  '동작구 사당1동',
#  '마포구 공덕동',
#  '송파구 잠실본동',
#  '동작구 대방동',
#  '동대문구 전농1동',
#  '은평구 대조동',
#  '성북구 동선동',
#  '중랑구 중화2동',
#  '구로구 구로5동',
#  '성북구 종암동',
#  '강북구 수유3동',
#  '동작구 노량진1동',
#  '성북구 삼선동',
#  '동대문구 제기동',
#  '강서구 등촌1동',
#  '서초구 반포1동',
#  '광진구 구의1동',
#  '양천구 신정4동',
#  '동대문구 장안1동',
#  '관악구 은천동',
#  '은평구 역촌동',
#  '강서구 화곡본동',
#  '송파구 방이2동',
#  '관악구 중앙동',
#  '용산구 청파동',
#  '종로구 혜화동',
#  '관악구 조원동',
#  '관악구 신원동',
#  '강서구 등촌3동',
#  '성북구 석관동',
#  '성동구 사근동',
#  '관악구 보라매동',
#  '서초구 양재1동',
# ...

# %%
seoul_list2
# Out:
# ['강남구 역삼1동',
#  '광진구 화양동',
#  '관악구 신림동',
#  '관악구 청룡동',
#  '관악구 대학동',
#  '강서구 가양1동',
#  '관악구 행운동',
#  '강서구 화곡1동',
#  '서대문구 연희동',
#  '서대문구 신촌동',
#  '영등포구 영등포동',
#  '동작구 상도1동',
#  '마포구 서교동',
#  '금천구 가산동',
#  '관악구 서림동',
#  '송파구 문정2동',
#  '동대문구 이문1동',
#  '금천구 독산1동',
#  '노원구 공릉1동',
#  '동대문구 용신동',
#  '강남구 논현1동',
#  '영등포구 당산2동',
#  '관악구 서원동',
#  '구로구 구로3동',
#  '관악구 신사동',
#  '관악구 인헌동',
#  '관악구 낙성대동',
#  '송파구 석촌동',
#  '광진구 군자동',
#  '마포구 성산2동',
#  '강동구 길동',
#  '중랑구 면목본동',
#  '송파구 삼전동',
#  '강동구 천호2동',
#  '성북구 안암동',
#  '동작구 사당1동',
#  '마포구 공덕동',
#  '송파구 잠실본동',
#  '동작구 대방동',
#  '동대문구 전농1동',
#  '은평구 대조동',
#  '성북구 동선동',
#  '중랑구 중화2동',
#  '구로구 구로5동',
#  '성북구 종암동',
#  '강북구 수유3동',
#  '동작구 노량진1동',
#  '성북구 삼선동',
#  '동대문구 제기동',
#  '강서구 등촌1동',
#  '서초구 반포1동',
#  '광진구 구의1동',
#  '양천구 신정4동',
#  '동대문구 장안1동',
#  '관악구 은천동',
#  '은평구 역촌동',
#  '강서구 화곡본동',
#  '송파구 방이2동',
#  '관악구 중앙동',
#  '용산구 청파동',
#  '종로구 혜화동',
#  '관악구 조원동',
#  '관악구 신원동',
#  '강서구 등촌3동',
#  '성북구 석관동',
#  '성동구 사근동',
#  '관악구 보라매동',
#  '서초구 양재1동',
# ...

# %%
gulist = []
donglist = []
for s in seoul_list2:
  var = s.split()
  gulist.append(var[0])
  donglist.append(var[1])

# %%
gulist
# Out:
# ['강남구',
#  '광진구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '강서구',
#  '관악구',
#  '강서구',
#  '서대문구',
#  '서대문구',
#  '영등포구',
#  '동작구',
#  '마포구',
#  '금천구',
#  '관악구',
#  '송파구',
#  '동대문구',
#  '금천구',
#  '노원구',
#  '동대문구',
#  '강남구',
#  '영등포구',
#  '관악구',
#  '구로구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '송파구',
#  '광진구',
#  '마포구',
#  '강동구',
#  '중랑구',
#  '송파구',
#  '강동구',
#  '성북구',
#  '동작구',
#  '마포구',
#  '송파구',
#  '동작구',
#  '동대문구',
#  '은평구',
#  '성북구',
#  '중랑구',
#  '구로구',
#  '성북구',
#  '강북구',
#  '동작구',
#  '성북구',
#  '동대문구',
#  '강서구',
#  '서초구',
#  '광진구',
#  '양천구',
#  '동대문구',
#  '관악구',
#  '은평구',
#  '강서구',
#  '송파구',
#  '관악구',
#  '용산구',
#  '종로구',
#  '관악구',
#  '관악구',
#  '강서구',
#  '성북구',
#  '성동구',
#  '관악구',
#  '서초구',
#  '강동구',
#  '동작구',
#  '강북구',
#  '노원구',
#  '강동구',
#  '금천구',
#  '강동구',
#  '동대문구',
#  '강남구',
#  '마포구',
#  '중랑구',
#  '강남구',
#  '은평구',
#  '영등포구',
#  '송파구',
#  '광진구',
#  '용산구',
#  '강북구',
#  '중랑구',
#  '구로구',
#  '강북구',
#  '은평구',
#  '강북구',
#  '강서구',
#  '강남구',
#  '강남구',
#  '중랑구',
#  '강남구',
#  '강서구',
#  '은평구',
# ...

# %%
donglist[0]
# Out:
# '역삼1동'

# %%
seoul
# Out:
#                행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구
# 0    서울특별시 강남구 역삼1동  11,588  3,374  7,328  15,733  32,466  35,865
# 1     서울특별시 광진구 화양동  11,276    421    739   2,354  24,186  21,441
# 2     서울특별시 관악구 신림동  10,468    312    494   1,613  20,279  21,363
# 3     서울특별시 관악구 청룡동  10,308    383    631   1,733  27,211  28,789
# 4     서울특별시 관악구 대학동   9,687    169    566   1,522  23,335  23,824
# ..              ...     ...    ...    ...     ...     ...     ...
# 419   서울특별시 송파구 오륜동     339    187    199     504  18,593  19,228
# 420  서울특별시 서초구 반포본동     312    230    257     665  10,978  12,528
# 421  서울특별시 송파구 잠실7동     270     63     76     194   9,267  10,355
# 422  서울특별시 강동구 둔촌1동      45      8      5      18     134     301
# 423  서울특별시 송파구 가락1동      14  2,538    105   2,784     708   1,104
#
# [424 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-a8ca37c40d04> in <module>()
# ----> 1 seoul_list2.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
seoul.head(1)
# Out:
#              행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구
# 0  서울특별시 강남구 역삼1동  11,588  3,374  7,328  15,733  32,466  35,865

# %%
seoul["행정구역"] = donglist

# %%
seoul["행정구역"]
# Out:
# 0      역삼1동
# 1       화양동
# 2       신림동
# 3       청룡동
# 4       대학동
#        ...
# 419     오륜동
# 420    반포본동
# 421    잠실7동
# 422    둔촌1동
# 423    가락1동
# Name: 행정구역, Length: 424, dtype: object

# %%
seoul["지약구"] = gulist

# %%
seoul
# Out:
#      행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구  지약구
# 0    역삼1동  11,588  3,374  7,328  15,733  32,466  35,865  강남구
# 1     화양동  11,276    421    739   2,354  24,186  21,441  광진구
# 2     신림동  10,468    312    494   1,613  20,279  21,363  관악구
# 3     청룡동  10,308    383    631   1,733  27,211  28,789  관악구
# 4     대학동   9,687    169    566   1,522  23,335  23,824  관악구
# ..    ...     ...    ...    ...     ...     ...     ...  ...
# 419   오륜동     339    187    199     504  18,593  19,228  송파구
# 420  반포본동     312    230    257     665  10,978  12,528  서초구
# 421  잠실7동     270     63     76     194   9,267  10,355  송파구
# 422  둔촌1동      45      8      5      18     134     301  강동구
# 423  가락1동      14  2,538    105   2,784     708   1,104  송파구
#
# [424 rows x 8 columns]

# %%
seoul = seoul.drop(columns = '지약구')

# %%
seoul["지역구"] = gulist

# %%
seoul
# Out:
#      행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구  지역구
# 0    역삼1동  11,588  3,374  7,328  15,733  32,466  35,865  강남구
# 1     화양동  11,276    421    739   2,354  24,186  21,441  광진구
# 2     신림동  10,468    312    494   1,613  20,279  21,363  관악구
# 3     청룡동  10,308    383    631   1,733  27,211  28,789  관악구
# 4     대학동   9,687    169    566   1,522  23,335  23,824  관악구
# ..    ...     ...    ...    ...     ...     ...     ...  ...
# 419   오륜동     339    187    199     504  18,593  19,228  송파구
# 420  반포본동     312    230    257     665  10,978  12,528  서초구
# 421  잠실7동     270     63     76     194   9,267  10,355  송파구
# 422  둔촌1동      45      8      5      18     134     301  강동구
# 423  가락1동      14  2,538    105   2,784     708   1,104  송파구
#
# [424 rows x 8 columns]

# %%
seoul.to_csv("최종서울전처리.csv")

# %%
seoul = seoul.sort_values(by='행정구역')

# %%
skt = pd.read_csv("/content/gdrive/Shared drives/2020 공공빅데이터 서울3반 9조/데이터팀/공동작업실/컬럼목록csv/skt_data.csv" ,encoding='cp949')

# %%
skt
# Out:
#       읍면동    통화건수   시군구    시군구읍면동
# 0     가락동  319396   송파구   송파구 가락동
# 1    가리봉동   23989   구로구  구로구 가리봉동
# 2     가산동  331207   금천구   금천구 가산동
# 3     가양동  333994   강서구   강서구 가양동
# 4     갈월동    5730   용산구   용산구 갈월동
# ..    ...     ...   ...       ...
# 374   효창동   14926   용산구   용산구 효창동
# 375   후암동  304288   용산구   용산구 후암동
# 376   휘경동   22761  동대문구  동대문구 휘경동
# 377   흑석동   18655   동작구   동작구 흑석동
# 378   흥인동   11597    중구    중구 흥인동
#
# [379 rows x 4 columns]

# %%
a = seoul['행정구역']
b = skt['읍면동']

# %%
a = list(a)

# %%
b = list(b)

# %%
temp = []
temp2 = []
for 동 in a:
  if 동 not in b:
    temp.append(동)


for 동 in b:
  if 동 not in a:
    temp2.append(동)

# %%
temp
# Out:
# ['가락1동',
#  '가락2동',
#  '가락본동',
#  '가양1동',
#  '가양2동',
#  '가양3동',
#  '가회동',
#  '갈현1동',
#  '갈현2동',
#  '개봉1동',
#  '개봉2동',
#  '개봉3동',
#  '개포1동',
#  '개포2동',
#  '개포4동',
#  '거여1동',
#  '거여2동',
#  '고덕1동',
#  '고덕2동',
#  '고척1동',
#  '고척2동',
#  '공릉1동',
#  '공릉2동',
#  '광희동',
#  '구로1동',
#  '구로2동',
#  '구로3동',
#  '구로4동',
#  '구로5동',
#  '구의1동',
#  '구의2동',
#  '구의3동',
#  '금호1가동',
#  '금호2·3가동',
#  '금호4가동',
#  '길음1동',
#  '길음2동',
#  '낙성대동',
#  '난곡동',
#  '난향동',
#  '남가좌1동',
#  '남가좌2동',
#  '남영동',
#  '노량진1동',
#  '노량진2동',
#  '논현1동',
#  '논현2동',
#  '다산동',
#  '답십리1동',
#  '답십리2동',
#  '당산1동',
#  '당산2동',
#  '대림1동',
#  '대림2동',
#  '대림3동',
#  '대치1동',
#  '대치2동',
#  '대치4동',
#  '대학동',
#  '도곡1동',
#  '도곡2동',
#  '도봉1동',
#  '도봉2동',
#  '독산1동',
#  '독산2동',
#  '독산3동',
#  '독산4동',
#  '돈암1동',
#  '돈암2동',
#  '동선동',
#  '동화동',
#  '둔촌1동',
#  '둔촌2동',
#  '등촌1동',
#  '등촌2동',
#  '등촌3동',
#  '마천1동',
#  '마천2동',
#  '망우3동',
#  '망우본동',
#  '망원1동',
#  '망원2동',
#  '면목2동',
#  '면목3·8동',
#  '면목4동',
#  '면목5동',
#  '면목7동',
#  '면목본동',
#  '명동',
#  '명일1동',
# ...

# %%
temp2
# Out:
# ['가락동',
#  '가양동',
#  '갈월동',
#  '갈현동',
#  '개봉동',
#  '개포동',
#  '거여동',
#  '견지동',
#  '경운동',
#  '계동',
#  '고덕동',
#  '고척동',
#  '공릉동',
#  '과해동',
#  '관수동',
#  '관철동',
#  '광희동1가',
#  '광희동2가',
#  '구기동',
#  '구로동',
#  '구수동',
#  '구의동',
#  '궁동',
#  '금호동1가',
#  '금호동2가',
#  '금호동4가',
#  '길음동',
#  '낙원동',
#  '남가좌동',
#  '남대문로1가',
#  '남대문로2가',
#  '남대문로3가',
#  '남대문로4가',
#  '남대문로5가',
#  '남창동',
#  '내발산동',
#  '내수동',
#  '내자동',
#  '노고산동',
#  '노량진동',
#  '논현동',
#  '다동',
#  '답십리동',
#  '당산동',
#  '당산동1가',
#  '당산동2가',
#  '당산동3가',
#  '당산동4가',
#  '당산동6가',
#  '당주동',
#  '대림동',
#  '대신동',
#  '대치동',
#  '대현동',
#  '도곡동',
#  '도봉동',
#  '도원동',
#  '독산동',
#  '돈암동',
#  '돈의동',
#  '동교동',
#  '동빙고동',
#  '동선동1가',
#  '동선동2가',
#  '동선동3가',
#  '동선동4가',
#  '동선동5가',
#  '동소문동2가',
#  '동소문동6가',
#  '동숭동',
#  '동자동',
#  '동작동',
#  '둔촌동',
#  '등촌동',
#  '마곡동',
#  '마천동',
#  '마포동',
#  '만리동1가',
#  '만리동2가',
#  '망우동',
#  '망원동',
#  '망월동',
#  '면목동',
#  '명동1가',
#  '명동2가',
#  '명륜1가',
#  '명륜3가',
#  '명륜4가',
#  '명일동',
#  '목동',
#  '묘동',
#  '무교동',
#  '묵동',
# ...

# %%
len(temp2)
# Out:
# 300

# %%
len(temp)
# Out:
# 344

# %%
temp3 = []

for 동 in b:
  if 동 in a:
    temp3.append(동)
len(temp3)
# Out:
# 79

# %%
len(b)
# Out:
# 379

# %%
len(a)
# Out:
# 424

# %%
len(temp)
# Out:
# 344

# %%
344+79
# Out:
# 423

# %%
seoul.head(1)
# Out:
#      행정구역 N1인가구변화   도소매업 서비스업   사업체수 인구변화 주민등록인구  지역구
# 423  가락1동      14  2,538  105  2,784  708  1,104  송파구

# %%
skt.head(1)
# Out:
#    읍면동    통화건수  시군구   시군구읍면동
# 0  가락동  319396  송파구  송파구 가락동

# %%
skt
# Out:
#       읍면동    통화건수   시군구    시군구읍면동
# 0     가락동  319396   송파구   송파구 가락동
# 1    가리봉동   23989   구로구  구로구 가리봉동
# 2     가산동  331207   금천구   금천구 가산동
# 3     가양동  333994   강서구   강서구 가양동
# 4     갈월동    5730   용산구   용산구 갈월동
# ..    ...     ...   ...       ...
# 374   효창동   14926   용산구   용산구 효창동
# 375   후암동  304288   용산구   용산구 후암동
# 376   휘경동   22761  동대문구  동대문구 휘경동
# 377   흑석동   18655   동작구   동작구 흑석동
# 378   흥인동   11597    중구    중구 흥인동
#
# [379 rows x 4 columns]

# %%
seoul
# Out:
#      행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구   지역구
# 423  가락1동      14  2,538    105   2,784     708   1,104   송파구
# 268  가락2동   2,042    407    702   1,673  32,018  34,243   송파구
# 177  가락본동   2,863  1,035  1,135   3,354  25,996  27,997   송파구
# 227  가리봉동   2,413    222    277     884   8,772   9,716   구로구
# 13    가산동   7,330  4,345  5,426  15,111  19,280  20,684   금천구
# ..    ...     ...    ...    ...     ...     ...     ...   ...
# 396   효창동     879     94    148     372   8,150   8,944   용산구
# 212   후암동   2,540    211    236     790  16,472  18,144   용산구
# 153  휘경1동   3,090    224    284     881  12,407  12,932  동대문구
# 75   휘경2동   4,250    141    209     607  23,767  24,561  동대문구
# 69    흑석동   4,316    289    455   1,414  30,135  30,617   동작구
#
# [424 rows x 8 columns]

# %%
skt
# Out:
#       읍면동    통화건수   시군구    시군구읍면동
# 0     가락동  319396   송파구   송파구 가락동
# 1    가리봉동   23989   구로구  구로구 가리봉동
# 2     가산동  331207   금천구   금천구 가산동
# 3     가양동  333994   강서구   강서구 가양동
# 4     갈월동    5730   용산구   용산구 갈월동
# ..    ...     ...   ...       ...
# 374   효창동   14926   용산구   용산구 효창동
# 375   후암동  304288   용산구   용산구 후암동
# 376   휘경동   22761  동대문구  동대문구 휘경동
# 377   흑석동   18655   동작구   동작구 흑석동
# 378   흥인동   11597    중구    중구 흥인동
#
# [379 rows x 4 columns]

# %%
교집합 = pd.read_csv("/content/gdrive/Shared drives/2020 공공빅데이터 서울3반 9조/데이터팀/공동작업실/컬럼목록csv/교집합.csv" ,encoding='cp949')

# %%
교집합.head(1)
# Out:
#    V1 행정구역 N1인가구변화 도소매업 서비스업   사업체수    인구변화  주민등록인구  지역구   통화건수  시군구   시군구읍면동
# 0   1  화양동  11,276  421  739  2,354  24,186  21,441  광진구  54903  광진구  광진구 화양동

# %%
seoul
# Out:
#      행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구   지역구
# 423  가락1동      14  2,538    105   2,784     708   1,104   송파구
# 268  가락2동   2,042    407    702   1,673  32,018  34,243   송파구
# 177  가락본동   2,863  1,035  1,135   3,354  25,996  27,997   송파구
# 227  가리봉동   2,413    222    277     884   8,772   9,716   구로구
# 13    가산동   7,330  4,345  5,426  15,111  19,280  20,684   금천구
# ..    ...     ...    ...    ...     ...     ...     ...   ...
# 396   효창동     879     94    148     372   8,150   8,944   용산구
# 212   후암동   2,540    211    236     790  16,472  18,144   용산구
# 153  휘경1동   3,090    224    284     881  12,407  12,932  동대문구
# 75   휘경2동   4,250    141    209     607  23,767  24,561  동대문구
# 69    흑석동   4,316    289    455   1,414  30,135  30,617   동작구
#
# [424 rows x 8 columns]

# %%
skt
# Out:
#       읍면동    통화건수   시군구    시군구읍면동
# 0     가락동  319396   송파구   송파구 가락동
# 1    가리봉동   23989   구로구  구로구 가리봉동
# 2     가산동  331207   금천구   금천구 가산동
# 3     가양동  333994   강서구   강서구 가양동
# 4     갈월동    5730   용산구   용산구 갈월동
# ..    ...     ...   ...       ...
# 374   효창동   14926   용산구   용산구 효창동
# 375   후암동  304288   용산구   용산구 후암동
# 376   휘경동   22761  동대문구  동대문구 휘경동
# 377   흑석동   18655   동작구   동작구 흑석동
# 378   흥인동   11597    중구    중구 흥인동
#
# [379 rows x 4 columns]

# %%
AUNIONB = pd.read_csv("/content/gdrive/Shared drives/2020 공공빅데이터 서울3반 9조/데이터팀/공동작업실/컬럼목록csv/ASUMB.csv" ,encoding='cp949')

# %%
AUNIONB.shape
# Out:
# (724, 12)

# %%
AUNIONB.columns
# Out:
# Index(['V1', '행정구역', 'N1인가구변화', '도소매업', '서비스업', '사업체수', '인구변화', '주민등록인구',
#        '지역구', '통화건수', '시군구', '시군구읍면동'],
#       dtype='object')

# %%
AUNIONB['통화건수'].
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-ebe85c76b454> in <module>()
# ...

# %%
AUNIONB[ AUNIONB['통화건수'].isnull() ]
# Out:
#         V1  행정구역 N1인가구변화   도소매업   서비스업    사업체수    인구변화  주민등록인구  지역구  통화건수  \
# 0      0.0  역삼1동  11,588  3,374  7,328  15,733  32,466  35,865  강남구   NaN
# 3      3.0   청룡동  10,308    383    631   1,733  27,211  28,789  관악구   NaN
# 4      4.0   대학동   9,687    169    566   1,522  23,335  23,824  관악구   NaN
# 5      5.0  가양1동   9,062  1,255  1,738   5,012  31,304  33,189  강서구   NaN
# 6      6.0   행운동   8,734    305    543   1,314  28,681  29,876  관악구   NaN
# ..     ...   ...     ...    ...    ...     ...     ...     ...  ...   ...
# 419  419.0   오륜동     339    187    199     504  18,593  19,228  송파구   NaN
# 420  420.0  반포본동     312    230    257     665  10,978  12,528  서초구   NaN
# 421  421.0  잠실7동     270     63     76     194   9,267  10,355  송파구   NaN
# 422  422.0  둔촌1동      45      8      5      18     134     301  강동구   NaN
# 423  423.0  가락1동      14  2,538    105   2,784     708   1,104  송파구   NaN
#
#      시군구 시군구읍면동
# 0    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
# ...

# %%
AUNION = AUNIONB[ AUNIONB['통화건수'].isnull() ]

# %%
AUNION.to_csv("aminusb.csv")

# %%
pwd
# Out:
# '/content'
